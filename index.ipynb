# %%
# %%html
# <style>.container { width:75% !important; }</style>
# <link rel='stylesheet' type='text/css' href='static/css_backup/mobile-package-094623.css'>
# <link rel='stylesheet' type='text/css' href='static/css_backup/homepage-package-3bd234.css'>
#
# <body>
#   <article id="homepage">
#     <a id="library-section"></a>
#     <div class="library-section">
#       <div class="section-separator library-section-separator">
#         <h2><span class="section-separator-text">Water Allocation System Tutorials</span></h2><hr/>
#         <p>Welcome to the WAS tranings page! These tutorials are designed for students and researchers with different levels of experience.
#         Those without a background in economics or water modeling should look through the Overview notebooks, while those with more experience
#         can go directly to their topic of interest.
#             </p><p>
#             This tutorial is completly web based, but WAS is not.  To actually use WAS, you will need to manually install
#             the program on your machine.  A big thanks to the <a href="http://mybinder.org/">mybinder.org team</a> for hosting these notebooks for free.</p>
#       </div>
#
#       <!--Comment: to change the color of the title or section, change the second h2 class argument and the third div
#             argument to either science, computing, humanities, test-prep or economics-finance-domain-->
#
#       <!--to change the number of rows per column, change the last number in 'pure-u-1-3'.
#        For example, to have three columns, change the value to 'pure-u-1-3'-->
#
#       <h2 class="domain-header economics-finance-domain"><a class="domain-title">Overview</a></h2>
#       <div class="pure-g domain-table-container economics-finance-domain">
#         <a class="subject-link pure-u-1-4" target="_blank" href="trainings/Intro_Theory.ipynb">Theory</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="trainings/Intro_Usage.ipynb">Usage</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="trainings/Intro_Analysis.ipynb">Analysis</a>
#         </div>
#       <p>This section is meant as a general overview. It should give you a short introduction to the main topics that
#           you need to understand to use WAS, and serve as a guide for basic usage and analysis of results.</p>
#
#       <h2 class="domain-header humanities"><a class="domain-title">Basic Functions</a></h2>
#       <div class="pure-g domain-table-container humanities">
#         <a class="subject-link pure-u-1-4" target="_blank" href="trainings/Water_Linkages.ipynb">Water Linkages</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="trainings/Water_Treatment.ipynb">Water Treatment and Recycling</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/basic_workflow.ipynb">Sustainability and Environment</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/basic_graph_visualization.ipynb">New Water Sources and Pumps</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/basic_data_input.ipynb">Sharing Water Sources</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/basic_data_output.ipynb">Social Policies</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/advanced_execution_configuration.ipynb">Droughts and Floods</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/advanced_caching.ipynb">Maintenence and Leakage</a>
#         </div>
#       <p>This section covers specific functions that WAS can perform.  Some users may want to use only one of these functions, while others
#         will want to take advantage of all WAS's features to build the most robust model possible .</p>
#
#       <h2 class="domain-header computing"><a class="domain-title">Advanced Usage</a></h2>
#       <div class="pure-g domain-table-container computing">
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/advanced_databases.ipynb">Matching Current Circumstances</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/advanced_resources_and_profiling.ipynb">Projecting Into the Future</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/advanced_commandline.ipynb">Population and Economic Growth</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/advanced_databases.ipynb">Agriculture </a>
#       </div>
#       <p>This section is for users who need to build highly robust models that consider a wide range of scenarios and factors.  Ambitious students
#         may also be interested in trying to use the functions described.</p>
#
#       <h2 class="domain-header test-prep"><a class="domain-title">Questions and Code</a></h2>
#       <div class="pure-g domain-table-container test-prep">
#         <a class="subject-link pure-u-1-4" target="_blank" href="https://gitter.im/MYWAS/Lobby?utm_source=share-link&utm_medium=link&utm_campaign=share-link">Ask a Question</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="static/manuals/was_gams.pdf">WAS GAMS code</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/resources_help.ipynb">WAS python code</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="../tree/trainings/EconGraphs.ipynb">Tutorial code</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="../tree/trainings">Show notebook tree</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="javascript:code_toggle()">Toggle page HTML</a>
#         </div>
#       <p>Directly access the notebooks and code behind the tutorials.</p>
#
#       <h2 class="domain-header math"><a class="domain-title">Useful Resources</a></h2>
#       <div class="pure-g domain-table-container math">
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/resources_installation.ipynb">Installation of WAS</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="static/manuals/was_examples.pdf">More examples</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="static/manuals/was_manuals.pdf">Full WAS documentation</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="static/manuals/was_math.pdf">Mathematical appendix</a>
#       </div>
#       <p>This section will give you helpfull links and resources, so that you always know where to go to should you ever get stuck
#         with this tutorial.</p>
#
#
#     </div>
#   </article>
# </body>
#
# <!--The following code will cause the code cell to disappear-->
#
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
#
# <hr/>
#
# The layout of this page was designed by Michael Notter for <a href="https://github.com/miykael/nipype_tutorial"> nipype tutorials</a> who adapted it from <a href="www.khanacademy.org/library">khan academy library</a>.
# Out:
# <style>.container { width:75% !important; }</style>
# <link rel='stylesheet' type='text/css' href='static/css_backup/mobile-package-094623.css'>
# <link rel='stylesheet' type='text/css' href='static/css_backup/homepage-package-3bd234.css'>
#
# <body>
#   <article id="homepage">
#     <a id="library-section"></a>
#     <div class="library-section">
#       <div class="section-separator library-section-separator">
#         <h2><span class="section-separator-text">Water Allocation System Tutorials</span></h2><hr/>
#         <p>Welcome to the WAS tranings page! These tutorials are designed for students and researchers with different levels of experience.
#         Those without a background in economics or water modeling should look through the Overview notebooks, while those with more experience
#         can go directly to their topic of interest.
#             </p><p>
# ...
