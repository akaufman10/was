# %%
# %%html
# <script>
#     // AUTORUN ALL CELLS ON NOTEBOOK-LOAD!
#     require(
#         ['base/js/namespace', 'jquery'],
#         function(jupyter, $) {
#             $(jupyter.events).on("kernel_ready.Kernel", function () {
#                 console.log("Auto-running all cells-below...");
#                 jupyter.actions.call('jupyter-notebook:run-all-cells-below');
#                 jupyter.actions.call('jupyter-notebook:save-notebook');
#             });
#         }
#     );
# </script>
# Out:
# <script>
#     // AUTORUN ALL CELLS ON NOTEBOOK-LOAD!
#     require(
#         ['base/js/namespace', 'jquery'],
#         function(jupyter, $) {
#             $(jupyter.events).on("kernel_ready.Kernel", function () {
#                 console.log("Auto-running all cells-below...");
#                 jupyter.actions.call('jupyter-notebook:run-all-cells-below');
#                 jupyter.actions.call('jupyter-notebook:save-notebook');
#             });
#         }
#     );
# </script>

# %%
# %%html
# <script>
#   ((window.gitter = {}).chat = {}).options = {
#     room: 'MYWAS/Lobby'
#   };
# </script>
# <script src="https://sidecar.gitter.im/dist/sidecar.v1.js" async defer></script>
# Out:
# <script>
#   ((window.gitter = {}).chat = {}).options = {
#     room: 'MYWAS/Lobby'
#   };
# </script>
# <script src="https://sidecar.gitter.im/dist/sidecar.v1.js" async defer></script>

# %% [markdown]
# # Introduction to Using WAS
#
# This notebook described the basic steps to using WAS.  If you are unsure about a concept or word that is used, please check the [Introduction to the Theory of WAS notebook](Intro_Theory.ipynb).
#
# ## Installing WAS
#
# WAS runs on Windows.  It requires instillation from a flash drive.  It also requires instillation of a program called GAMS.  Talk to Alex about getting everything installed.
#
# ## Basic Usage
#
# WAS is installed along with current data for water supply, demand, and infrastructure in Israel, Jordan, and Palestine.  All of the data is already built in, and a default model of the water system is in place.  The default model describes the water system in Israel, Jordan, and Palestine as it exists today.  Without making any changes or adding data, the user can determine the optimal water allocation in the default model.  If you want to examine the current supply and demand data, you can do so using the tools under Supply and Demand, described in the Data section below.  This section focusus on how to operate the model:
#
#
# When WAS is opened, it looks like this:
#
# ![main menu][home]
#
#
# Choose a year from the "Year" menu:
#
# ![select year][home-year]
#
# and click the Optimize button.  This will use an algorithm to determine the socially optimal water allocation given the existing constraints.
#
# ![run model][home-optimize]
#
# You will be prompted to enter a name for the scenario each time you run the model after making modifications.
#
# ![select name][select-scn-name]
#
# The following command output shows that the model was run successfully:
#
# ![completed][command-output]
#
# View the raw output of the model using the "Tabular" button, which shows tables of results.
#
# ![view output][view-output]
#
# View the results visually by using the schematic viewer, located in the bottom center of the interface
#
# ![view schematic][view-schematic]
#
# The schematic viewer shows geographic information about prices, social welfare, and other factors.  You can select the information that you want to view by using the top menu.
#
# ![schematic output][schematic-view]
#
# Once you are satisfied with your model, you should save the model and results so they can be loadad again later.
#
# ![save scn][save-scn]
#
# For more detailed analysis of models and results, we use Qlik, a free could-based analytics platform.  See the [Introduction to the Analysis of WAS notebook]().
#
#
#
#
# ## Comparing Scenarios
#
# Most users will want to use WAS to compare different scenarios.  To do so, we must create two scenarios.  In the previous example we created a scenario with for the year 1995.  Now create a new scenario for the year 2010 following the same process above.
#
# To compare the scenarios, open the schematic results viewer
#
# ![view schematic][view-schematic]
#
# and select compare scenarios
#
# ![compare scn][compare-scn]
#
# Once you have selected the scenario for comparison, the values for the selected scenario will appear in red below the values for the current scenario.  You can also see the name of the comparison scenario on the lower right side.
#
# ![two scn][two-scn]
#
# That is basically all you need to know for basic usage.  For instructions on how to change different scenario settings, such as water sharing, demand shifts, or cost-benefit analysis, use the notebooks linked in the [Index](http://mybinder.org/repo/akaufman10/was)
#
# ## Default Data
#
# The WAS model contains default data that is used to determine supply and demand.  The user can view, edit, and reset this data to the defualt using the Supply and Demand menus.
#
# ### Demand Data
#
# The demand function uses population data and other assumptions (which are also derived from data) to determine the quantity of water demanded at different prices in each region.  The function has the form $$ Q=AP^{\eta} $$ where $$ Q\ =\ Quantity\ of\ water\ demanded $$ $$ A\ =\ Multiplier $$ $$ P\ =\ Population $$ $$ \eta\ =\ Elasticity\ Parameter $$  Each part of the function can be viewed, adjusted, and reset by the user using the demand menu.  Remember, the demand function calculates the demand curve, not an actualy quantity to be supplies. An graph of the demand function is shown below.
#
#
# [home]: https://github.com/akaufman10/was/blob/master/static/screenshots/home.png?raw=true
# [home-year]: https://github.com/akaufman10/was/blob/master/static/screenshots/home-year.png?raw=true
# [home-optimize]: https://github.com/akaufman10/was/blob/master/static/screenshots/home-optimize.png?raw=true
# [select-scn-name]: https://github.com/akaufman10/was/blob/master/static/screenshots/select-scn-name.png?raw=true
# [command-output]: https://github.com/akaufman10/was/blob/master/static/screenshots/complete.png?raw=true
# [view-output]: https://github.com/akaufman10/was/blob/master/static/screenshots/view-output.png?raw=true
# [view-schematic]: https://github.com/akaufman10/was/blob/master/static/screenshots/view-schematic.png?raw=true
# [schematic-view]: https://github.com/akaufman10/was/blob/master/static/screenshots/schematic-view.png?raw=true
# [save-scn]: https://github.com/akaufman10/was/blob/master/static/screenshots/save-scn.png?raw=true
# [compare-scn]: https://github.com/akaufman10/was/blob/master/static/screenshots/compare-scn.png?raw=true
# [two-scn]: https://github.com/akaufman10/was/blob/master/static/screenshots/two-scn.png?raw=true

# %%
# %pylab inline
from __future__ import print_function
from econgraphs import graphMaker

graphMaker.drawDemand()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# To view the current demand menu, use the edit button under the demand section.
#
# ![demand window][demand-window]
#
# The population data can be viewed and edited by selecting the "modify data" button next to "Population."
#
# ![demand-pop][demand-pop]
#
# You may notice that the population data changes depending on the year you have selected, based on WAS projections.
#
# The elasticity paratmeters for each regions' demand curve can be viewed and edited by selecting a demand type from the menu next to Demand Elasticities.
#
# ![demand-mult][demand-mult]
#
# If you click the "Default Elasticities" button (the red square), you will reset all demand curves to their default elasticities.
#
# The multiplier for each regions' demand curve can be viewed and edited by selecting a demand type from the menu next to Demand Elasticities.
#
# ![demand-mult][demand-elas]
#
#
# If you click the "Default Elasticities" button (the red square), you will reset all demand curves to their default multipliers.
#
# Remember to click the "Finished" button to save any changes you make.
#
# ![demand-finished][demand-finished]
#
# #### Supply Data
#
# The supply function is based on data that describe the costs of producing water in each region.  The supply function is a step function, as shown below
#
# [demand-window]: https://github.com/akaufman10/was/blob/master/static/screenshots/demand-window.png?raw=true
# [demand-pop]: https://github.com/akaufman10/was/blob/master/static/screenshots/demand-pop.png?raw=true
# [demand-mult]: https://github.com/akaufman10/was/blob/master/static/screenshots/demand-mult.png?raw=true
# [demand-elas]: https://github.com/akaufman10/was/blob/master/static/screenshots/demand-elas.png?raw=true
# [demand-finished]: https://github.com/akaufman10/was/blob/master/static/screenshots/demand-finished.png?raw=true

# %%
graphMaker.drawFigure(drawSurplus=False)

# %% [markdown]
# For an explanation of the shape of the supply function, see **The costs of providing water** in the [theory notebook](./Intro_Theory.ipynb).
#
# The supply function steps are described by specifiying a price and capacity for each water source, as shown below.
#
# ![supply steps][supply-steps]
#
# Notice that 999 represents a non-existant price (not 0).
#
# To access this window, click the edit button next to "Supply of Water"
#
# ![supply window][supply-window]
#
#
# Then choose "Supply Step" and pick a country to view the supply step data.
#
# ![open steps][open-steps]
#
# ![supply country][supply-country]
#
#
# If you make any changes, rememebr to select "Finished" and then "Accept" in the previous menu to save changes.
#
# ![supply window fin][supply-window-finished]
#
# ![supply country accept][supply-country-accept]
#
#
#
# [supply-steps]: https://github.com/akaufman10/was/blob/master/static/screenshots/supply-steps.png?raw=true
# [supply-window]: https://github.com/akaufman10/was/blob/master/static/screenshots/supply-window.png?raw=true
# [open-steps]: https://github.com/akaufman10/was/blob/master/static/screenshots/open-steps.png?raw=true
# [supply-country]: https://github.com/akaufman10/was/blob/master/static/screenshots/supply-country.png?raw=true
# [supply-steps-finished]: https://github.com/akaufman10/was/blob/master/static/screenshots/supply-steps-finished.png?raw=true
# [supply-country-accept]: https://github.com/akaufman10/was/blob/master/static/screenshots/supply-country-accept.png?raw=true
